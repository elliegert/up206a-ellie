# %%
# for data wrangling
import pandas as pd

# for spatial
import geopandas as gpd

# for plotting
import matplotlib.pyplot as plt

# for basemaps
import contextily as ctx

# %%
gdf = gpd.read_file('lights_buffer_timecode.geojson')

# %%
gdf
# Out:
#         ID   Longitude   Latitude  \
# 0   184240 -118.466162  34.194008
# 1   184324 -118.274077  33.945564
# 2   184104 -118.291552  33.931004
# 3    97673 -118.476700  34.221359
# 4   184135 -118.397622  34.193943
# ..     ...         ...        ...
# 77  154627 -118.346980  34.097980
# 78  221122 -118.311170  33.945446
# 79   54862 -118.436607  33.934052
# 80  137988 -118.398205  34.243488
# 81  170646 -118.506133  34.332561
#
#                                              Location  time_code  \
# 0        SEPULVEDA BLVD & VANOWEN ST, LOS ANGELES, CA          1
# 1             CENTURY BLVD & MAIN ST, LOS ANGELES, CA          1
# 2         IMPERIAL HWY & VERMONT AVE, LOS ANGELES, CA          1
# 3          ROSCOE BLVD & HASKELL AVE, LOS ANGELES, CA          1
# 4           VANOWEN ST & VANTAGE AVE, LOS ANGELES, CA          1
# ..                                                ...        ...
# 77         SUNSET BLVD & FORMOSA AVE, LOS ANGELES, CA          3
# ...
